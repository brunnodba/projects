# %%
#!pip install matplotlib

# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.9.2'

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
mes = ['jan', 'fev', 'mar', 'abr', 'mai', 'jun', 'jul', 'ago']
temperatura = [29, 26, 25, 20, 18, 17, 16, 18]

# %%
#Marcacao Ticks Eixo X (Largura/Widgth)
mes
# Out:
# ['jan', 'fev', 'mar', 'abr', 'mai', 'jun', 'jul', 'ago']

# %%
#Marcacao Ticks Eixo Y (Altura/Height)
temperatura
# Out:
# [29, 26, 25, 20, 18, 17, 16, 18]

# %%
#Criar Legenda/X-Label/Y-Label/Title Grids para melhorar visualização

# %%
help(plt.plot)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 help(plt.plot)
#
# NameError: name 'plt' is not defined

# %%
plt.plot(mes,temperatura)
plt.show() #ou ;

# %%
plt.plot(mes,temperatura, linestyle = 'dashed', linewidth = 3, markersize = 5);

# %%
plt.plot(mes,temperatura, linestyle = 'dashed', linewidth = 3)

# %%
plt.plot(mes,temperatura, 'bo')

# %%
plt.plot(mes,temperatura, 'bo', color='green', marker=11)
# Out:
# C:\Users\BAA0813BR\AppData\Local\Temp\ipykernel_37000\1097163771.py:1: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "bo" (-> marker='o'). The keyword argument will take precedence.
#   plt.plot(mes,temperatura, 'bo', color='green', marker=11)
# C:\Users\BAA0813BR\AppData\Local\Temp\ipykernel_37000\1097163771.py:1: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "bo" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(mes,temperatura, 'bo', color='green', marker=11)

# %%
plt.pie(temperatura);

# %%
plt.scatter(mes,temperatura)

# %%
plt.step(mes,temperatura)

# %%
plt.hist2d(temperatura,temperatura);

# %%
plt.stackplot(mes,temperatura)

# %%
plt.figure(figsize=(12,8))
plt.bar(
      mes
    , temperatura
)
plt.yticks([0,10,20,30,40])
plt.xlabel('Meses')
plt.ylabel('Temperatura')
plt.title('Temperatura em 2023')
plt.grid(axis='y')
#plt.grid(axis='x')
plt.legend('Temperatura')

# %%
plt.bar(mes, temperatura);
